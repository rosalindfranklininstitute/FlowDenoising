# %% [markdown]
# Test installed package

# %%
import flowdenoising.flowdenoising_mod as fdnm

# %%
import mrcfile
import matplotlib.pyplot as plt
import logging

# %%
logging.basicConfig(level=logging.INFO)

# %%
with mrcfile.open(r"tempdata2.mrc", mode="r+") as mrcfile0:
    data=mrcfile0.data

# %%
filter = fdnm.cFlowDenoiser() #Can put adjust several paramters here when initializing class
# Out:
# INFO:root:Number of processing units: 8

# %%
data_filtered = filter.runOpticalFlow(data)
# Out:
# INFO:root:shape of the input volume (Z, Y, X) = (100, 256, 256)
# INFO:root:type of the volume = uint16
# INFO:root:vol requires 12.5 MB
# INFO:root:data max = 255
# INFO:root:data min = 0
# INFO:root:Input vol average = 164.55193878173827
# INFO:root:sigma=(2.0, 2.0, 2.0)
# INFO:root:length of each filter (Z, Y, X) = [17, 17, 17]
# INFO:root:Filtering ...
# INFO:root:self.calculation_interrupt:False
# INFO:root:stopEv.is_set():False
# INFO:root:Filtering along Z
# INFO:root:0/612 completed
# INFO:root:axis_dim:100
# INFO:root:self.max_number_of_processes:8
# INFO:root:n_remain_slices:4
# INFO:root:chunk_indexes:[0, 12, 24, 36, 48, 60, 72, 84, 96]
# INFO:root:chunk_sizes:[12, 12, 12, 12, 12, 12, 12, 12, 4]
# INFO:root:axis_i_s:[0, 0, 0, 0, 0, 0, 0, 0, 0]
# INFO:root:Starting threads
# INFO:root:8/612 completed
# INFO:root:24/612 completed
# INFO:root:37/612 completed
# INFO:root:54/612 completed
# INFO:root:69/612 completed
# INFO:root:88/612 completed
# INFO:root:99/612 completed
# ...

# %%
fig,axs = plt.subplots(1,2,figsize=(8,8))

axs[0].imshow(data[50,:,:])
axs[1].imshow(data_filtered[50,:,:])
# Out:
# INFO:root:feedback_periodic thread stopped.
