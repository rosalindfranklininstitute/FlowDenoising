# %%
# !python ../src/flowdenoisingRFI_threaded.py -i "tempdata.mrc" -o "result_threaded_shell.mrc" -v 1
# Out:
# levels:3
# winsize:5
# self.calculation_interrupt:False
# stopEv.is_set():False
# [2023-06-28 00:33:36,076] (INFO) Verbosity level = 1
# [2023-06-28 00:33:36,076] (INFO) reading "tempdata.mrc"
# [2023-06-28 00:33:36,083] (INFO) read "tempdata.mrc" in 0.007036399998469278 seconds
# [2023-06-28 00:33:36,083] (INFO) Number of processing units: 8
# [2023-06-28 00:33:36,083] (INFO) shape of the input volume (Z, Y, X) = (100, 256, 256)
# [2023-06-28 00:33:36,083] (INFO) type of the volume = uint16
# [2023-06-28 00:33:36,083] (INFO) vol requires 12.5 MB
# [2023-06-28 00:33:36,084] (INFO) data max = 255
# [2023-06-28 00:33:36,084] (INFO) data min = 0
# [2023-06-28 00:33:36,089] (INFO) Input vol average = 163.69832733154297
# [2023-06-28 00:33:36,089] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-06-28 00:33:36,089] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-06-28 00:33:36,089] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %% [markdown]
# This appears to be working ok
