# %%
# !python ../src/flowdenoisingRFI_threaded.py -i "tempdata.mrc" -o "result_threaded.mrc" -v 1
# Out:
# levels:3
# winsize:5
# self.calculation_interrupt:False
# stopEv.is_set():False
# [2023-06-28 00:15:26,866] (INFO) Verbosity level = 1
# [2023-06-28 00:15:26,867] (INFO) reading "tempdata.mrc"
# [2023-06-28 00:15:26,873] (INFO) read "tempdata.mrc" in 0.006336400008876808 seconds
# [2023-06-28 00:15:26,873] (INFO) Number of processing units: 8
# [2023-06-28 00:15:26,873] (INFO) shape of the input volume (Z, Y, X) = (100, 256, 256)
# [2023-06-28 00:15:26,873] (INFO) type of the volume = uint16
# [2023-06-28 00:15:26,873] (INFO) vol requires 12.5 MB
# [2023-06-28 00:15:26,874] (INFO) data max = 255
# [2023-06-28 00:15:26,875] (INFO) data min = 0
# [2023-06-28 00:15:26,881] (INFO) Input vol average = 163.69832733154297
# [2023-06-28 00:15:26,881] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-06-28 00:15:26,881] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-06-28 00:15:26,881] (INFO) Computing gaussian kernel with sigma=2.0
# ...
