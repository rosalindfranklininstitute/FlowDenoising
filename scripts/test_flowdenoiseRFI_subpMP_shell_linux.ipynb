# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !conda info
# Out:
#      active environment : p10dev
#     active env location : /home/luis/miniconda3/envs/p10dev
#             shell level : 2
#        user config file : /home/luis/.condarc
#  populated config files :
#           conda version : 23.1.0
#     conda-build version : not installed
#          python version : 3.8.16.final.0
#        virtual packages : __archspec=1=x86_64
#                           __cuda=12.1=0
#                           __glibc=2.31=0
#                           __linux=5.10.16.3=0
#                           __unix=0=0
#        base environment : /home/luis/miniconda3  (writable)
#       conda av data dir : /home/luis/miniconda3/etc/conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/linux-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/linux-64
#                           https://repo.anaconda.com/pkgs/r/noarch
# ...

# %%
# !python ../src/flowdenoising/flowdenoising_mod.py -i "tempdata2.mrc" -o "result_subpMP_shell_linux.tiff" -v 2 --procmode multiproc
#--procmode", choices=['threaded', 'sequential','multiproc']
# Out:
# [2023-07-05 23:55:31,815] (INFO) Verbosity level = 2
# [2023-07-05 23:55:31,816] (INFO) reading "tempdata2.mrc"
# [2023-07-05 23:55:31,816] (DEBUG) input = tempdata2.mrc
# [2023-07-05 23:55:31,816] (INFO) Input file is MRC
# [2023-07-05 23:55:31,845] (INFO) read "tempdata2.mrc" in 0.029107848000421654 seconds
# [2023-07-05 23:55:31,845] (INFO) args : Namespace(input='tempdata2.mrc', output='result_subpMP_shell_linux.tiff', sigma=(2.0, 2.0, 2.0), levels=3, winsize=5, verbosity=2, no_OF=False, number_of_processes=8, recompute_flow=False, timeout=30, procmode='multiproc')
# [2023-07-05 23:55:31,845] (INFO) Number of processing units: 8
# [2023-07-05 23:55:31,845] (DEBUG) Computing gaussian kernel with sigma=2.0
# [2023-07-05 23:55:31,846] (DEBUG) Kernel computed
# [2023-07-05 23:55:31,846] (DEBUG) Computing gaussian kernel with sigma=2.0
# [2023-07-05 23:55:31,846] (DEBUG) Kernel computed
# [2023-07-05 23:55:31,846] (DEBUG) Computing gaussian kernel with sigma=2.0
# ...

# %% [markdown]
# not working in Linux. There is some issue with resource tracker and shared memory
#
# local tests run fine, so I am not sure why this is happening
#
# Nevertheless it runs and the results seem ok
